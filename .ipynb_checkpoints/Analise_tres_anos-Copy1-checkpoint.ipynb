# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfFinal = pd.read_csv('dfFinal_17-19_sample.csv')
#df2017 = pd.read_csv('df2017.csv')
#df2017['DATA_TRAT.'] = pd.to_datetime(df2017['DATA_TRAT.'])
#
#df2018 = pd.read_csv('df2018.csv')
#df2018['DATA_TRAT.'] = pd.to_datetime(df2018['DATA_TRAT.'])
#
#df2019 = pd.read_csv('df2019.csv')
#df2019['DATA_TRAT.'] = pd.to_datetime(df2019['DATA_TRAT.'])

# %%
## Separando o produto Zero de São Paulo



## 2017
dfFinal = dfFinal.loc[dfFinal['UF'] == 'SP']
dfFinal = dfFinal.loc[dfFinal['SAP+NOME'] == dfFinal['SAP+NOME'].unique()[0]]
#
### 2018
#df2018_sp = df2018.loc[df2018['UF'] == 'SP']
#df2018_sp_prod = df2018_sp.loc[df2018_sp['SAP+NOME'] == df2018_sp['SAP+NOME'].unique()[0]]
#
### 2019
#df2019_sp = df2019.loc[df2019['UF'] == 'SP']
#df2019_sp_prod = df2019_sp.loc[df2019_sp['SAP+NOME'] == df2019_sp['SAP+NOME'].unique()[0]]

# %%
f, ax = plt.subplots(figsize = (25, 15))

dfFinal.plot(x = "DATA_TRAT.", y = "Preço",
               kind = "line",
               color = 'b',
               label = "2017", ax = ax)

plt.show();

# %%
#f, ax = plt.subplots(figsize = (25, 15))
#
#dfFinal.plot(x = "DATA_TRAT.", y = "Preço",
#               kind = "line",
#               color = 'r',
#               label = "2017", ax = ax)

##df2018_sp_prod.plot(x = "DATA_TRAT.", y = "Preço",
##               kind = "line",
##               color = 'b',
##               label = "2018", ax = ax)
##
##df2019_sp_prod.plot(x = "DATA_TRAT.", y = "Preço",
##               kind = "line",
##               color = 'g',
##               label = "2019", ax = ax)
plt.show();

# %%
#df2018['DATA_TRAT.'] = df2018['DATA_TRAT.'].replace('2018',)

# %%
dfFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1086 entries, 16209 to 17294
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SAP+NOME               1086 non-null   object
#  1   UF                     1086 non-null   object
#  2   DATA_TRAT.             1086 non-null   object
#  3   Vendas Reais Qtde      1086 non-null   float64
#  4   Vendas Reais $         1086 non-null   float64
#  5   CMV                    1086 non-null   float64
#  6   Margem Líquida Real %  1086 non-null   float64
#  7   Margem Líquida Real $  1086 non-null   float64
#  8   Venda Líquida Real $   1086 non-null   float64
#  9   Preço                  1086 non-null   float64
#  10  preço2                 1086 non-null   float64
#  11  CMV/QTD                1086 non-null   float64
#  12  Mg %                   1086 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 118.8+ KB
